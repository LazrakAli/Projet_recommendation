# %%
import pandas as pd

# %%
avis = pd.read_csv("BDD/avis_sans_outliers.csv")

# %%
avis.loc[avis['note']==10].value_counts()
# Out:
# Unnamed: 0  author           date_published  title_review                      note  title                                  url                                                                                           comment
# 35          Jones            2020-11         Chapeau l'artiste                 10    Mysterium Park                         https://www.trictrac.net/jeu-de-societe/mysterium-park/avis?limit=10000                       En famille nous avons bien poncé son grand frère (Mysterium, tout court) et nous nous sommes jetés sur les extensions avec délectation.\nSur ma critique de l'ainé, j'avais mentionné la légère lourdeur de quelques mécanismes que nous avions tout simplement et délibérément ignorés.\n\nEt là, Mysterium revient dans sa version épurée. Finies les mises en place un peu fastidieuses et les manipulations fréquentes des tas de cartes, ou une dernière phase un peu laborieuse. On obtient exactement le même résultat : c'est fort les gars. La préparation du jeu, son démarrage et sa conclusion sont devenus d'une facilité déconcertante, le tout pour des sensations identiques.\n\nJ'avais beaucoup aimé l'ainé, j'ai adoré Park :)\n\nCerise sur le gâteau, et même si ce n'est pas indiqué sur la boite, rien ne vous empêche de réutiliser tout le matos de cartes du grand frère, y compris ajouter la découverte de l'arme ou  de la circonstance du drame, pour ceux qui ont l'extension, et ainsi rallonger le plaisir en jouant en 4 étapes au lieu de 2 (tout en gardant la résolution des règles de Park par contre). Vous perdez sur le thème mais Mysterium premier du nom ne finit pas aux oubliette, ce qui serait dommage.\n\nBref un sans faute pour un prix très accessible et un encombrement réduit (petite boite) que l'espace ludo remercie. Fanboy et j'assume :)    1
# 118682      wizz50           2008-07         Encore plus fort !!               10    Les Piliers de la Terre : L'extension  https://www.trictrac.net/jeu-de-societe/les-piliers-de-la-terre-l-extension/avis?limit=10000  Déjà que le jeu de base est extraordinaire, mais avec l'extension, c'est carrément dément !!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# 118697      thobil-7         2008-08         Très bien à 2 - Top à 5 !!        10    Les Piliers de la Terre : L'extension  https://www.trictrac.net/jeu-de-societe/les-piliers-de-la-terre-l-extension/avis?limit=10000  Testée à 2 joueurs et 5 joueurs.Cette extension est très belle et est parfaitement intégrée au plateau de base. Mais ce n'est pas tout, même à 2 joueurs, l'extension complète bien le jeu (on peut se sentir un peu plus perdu face à tant de possibilités). Elle n'est peut-être pas indispensable à 2, mais les 2 plateaux sont tellement chouettes !! La nouvelle carte Saint Denis rajoute aussi un peu d'interaction.A 5 : c'est le pied. Ce jeu est facile à expliquer aux novices, très facile à jouer, il y a toujours quelque chose d'intéressant à faire même pour les moins tacticiens (comme envoyer des ouvriers en croisade pour ramener directement des points de victoire), peut-être au détriment des plus tacticiens.Le top du top ???                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# 118696      sambot           2009-04         Que du bon!                       10    Les Piliers de la Terre : L'extension  https://www.trictrac.net/jeu-de-societe/les-piliers-de-la-terre-l-extension/avis?limit=10000  le jeu de base était déja bien fourni et les posibilités grandes...mais il faut avouer qu'a 4 cela commençait a etre juste, a notre grand bonheur filosofia nous a sortie cette superbe extension pour un plateau XXL! Que du bon!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# 176196      duinhir          2008-11         Bam bam, wizz, zap!               10    Mag Blast                              https://www.trictrac.net/jeu-de-societe/mag-blast-1/avis?limit=10000                          Un jeu simple, rigolo et rapide... 5/5, rien à ajouter                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Name: count, Length: 21934, dtype: int64

# %%
from surprise import accuracy

# Function to calculate MAE for a specific rating
def calculate_mae_for_specific_rating(predictions, rating):
    # Filtering predictions for the specified rating
    filtered_predictions = [pred for pred in predictions if pred.r_ui == rating]
    
    # Calculating MAE for the filtered predictions
    if filtered_predictions:
        mae = accuracy.mae(filtered_predictions, verbose=False)
        return mae
    else:
        return None

# %%
from surprise import KNNBasic
from surprise import KNNWithMeans
from surprise import KNNWithZScore
from surprise import KNNBaseline

# Configure the algorithm to compute similarities between items
sim_options = {
    'name': 'cosine',
    'user_based': False  # Compute similarities between items
}

# Define bsl_options (if you want to customize baseline configurations)
"""
bsl_options = {
    'method': 'sgd',
    'learning_rate': .00005,
}
"""

# %%
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate, train_test_split
from surprise.accuracy import mae

# Assuming you've already loaded your data into a 'data' variable

# Example dataset loading, replace with your actual data loading code
reader = Reader(line_format='user item rating', rating_scale=(0, 10))
data = Dataset.load_from_df(avis[['author', 'title', 'note']], reader)

trainset, testset = train_test_split(data, test_size=0.2)

# List of algorithms to evaluate
algorithms = [
    #KNNBasic(sim_options={'name': 'cosine', 'user_based': True}),
    KNNWithMeans(k=20,sim_options={'name': 'cosine', 'user_based': True}),
    KNNWithZScore(k=20,sim_options={'name': 'cosine', 'user_based': True}),
    #KNNBaseline(sim_options={'name': 'cosine', 'user_based': True}, bsl_options={'method': 'sgd', 'learning_rate': .00005})
]

for algo in algorithms:
    print(f"\nEvaluating {algo.__class__.__name__}...")
    algo.fit(trainset)
    predictions = algo.test(testset)
    for i in range(11):
        mae = calculate_mae_for_specific_rating(predictions, i)
        if mae is not None:
            print(f'MAE for rating {i}: {mae}')
        else:
            print(f'No predictions found for rating {i}')
    print(f'MAE {accuracy.mae(predictions, verbose=False)}')
# Out:
# Evaluating KNNWithMeans...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# No predictions found for rating 0
# No predictions found for rating 1
# No predictions found for rating 2
# No predictions found for rating 3
# MAE for rating 4: 2.798961624344402
# MAE for rating 5: 1.6856896230399718
# MAE for rating 6: 1.193122636521836
# MAE for rating 7: 0.7288198475961436
# MAE for rating 8: 0.7724444472101837
# MAE for rating 9: 0.9036739962724859
# MAE for rating 10: 1.7278472244394836
# MAE 1.2515788285191283
#
# Evaluating KNNWithZScore...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# No predictions found for rating 0
# No predictions found for rating 1
# No predictions found for rating 2
# No predictions found for rating 3
# MAE for rating 4: 2.774176470525486
# MAE for rating 5: 1.6686615216916418
# MAE for rating 6: 1.1969732193931777
# MAE for rating 7: 0.7107865495429324
# MAE for rating 8: 0.7832487628292228
# MAE for rating 9: 0.8873488439010084
# MAE for rating 10: 1.7128858946202117
# MAE 1.2472805381049548

# %%
from surprise import Dataset, Reader, KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline
from surprise.model_selection import train_test_split
from surprise.accuracy import mae

# Example dataset loading, replace with your actual data loading code
reader = Reader(line_format='user item rating', rating_scale=(0, 10))
# Replace 'avis[['author', 'title', 'note']]' with your DataFrame
data = Dataset.load_from_df(avis[['author', 'title', 'note']], reader)

trainset, testset = train_test_split(data, test_size=0.2)

# k values to test for each algorithm
k_values = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

best_mae = float('inf')
best_algo = None
best_k = None

for k in k_values:
    algorithms = [
        KNNWithMeans(k=k, sim_options={'name': 'cosine', 'user_based': True}),
        KNNWithZScore(k=k, sim_options={'name': 'cosine', 'user_based': True}),
    ]

    for algo in algorithms:
        print(f"\nEvaluating {algo.__class__.__name__} with k={k}...")
        algo.fit(trainset)
        predictions = algo.test(testset)
        current_mae = mae(predictions, verbose=False)
        
        print(f'MAE: {current_mae} for {algo.__class__.__name__} with k={k}')
        
        if current_mae < best_mae:
            best_mae = current_mae
            best_algo = algo.__class__.__name__
            best_k = k

print(f'\nBest algorithm: {best_algo} with k={best_k} having MAE: {best_mae}')
# Out:
# Evaluating KNNWithMeans with k=5...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.3122265277315108 for KNNWithMeans with k=5
#
# Evaluating KNNWithZScore with k=5...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.307824134740411 for KNNWithZScore with k=5
#
# Evaluating KNNWithMeans with k=10...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2688612272021416 for KNNWithMeans with k=10
#
# Evaluating KNNWithZScore with k=10...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2647595070211073 for KNNWithZScore with k=10
#
# Evaluating KNNWithMeans with k=15...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2531718458717398 for KNNWithMeans with k=15
#
# Evaluating KNNWithZScore with k=15...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2494571519546283 for KNNWithZScore with k=15
#
# Evaluating KNNWithMeans with k=20...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2462708237586346 for KNNWithMeans with k=20
#
# Evaluating KNNWithZScore with k=20...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.242452144929866 for KNNWithZScore with k=20
#
# Evaluating KNNWithMeans with k=25...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.242069713686625 for KNNWithMeans with k=25
#
# Evaluating KNNWithZScore with k=25...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2385721473426585 for KNNWithZScore with k=25
#
# Evaluating KNNWithMeans with k=30...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2394925313604013 for KNNWithMeans with k=30
#
# Evaluating KNNWithZScore with k=30...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2357916895234842 for KNNWithZScore with k=30
#
# Evaluating KNNWithMeans with k=35...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2378223646035613 for KNNWithMeans with k=35
#
# Evaluating KNNWithZScore with k=35...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.234167192342628 for KNNWithZScore with k=35
#
# Evaluating KNNWithMeans with k=40...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.23618729180328 for KNNWithMeans with k=40
#
# Evaluating KNNWithZScore with k=40...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.232286389867207 for KNNWithZScore with k=40
#
# Evaluating KNNWithMeans with k=45...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2349684295158414 for KNNWithMeans with k=45
#
# Evaluating KNNWithZScore with k=45...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.231282413870532 for KNNWithZScore with k=45
#
# Evaluating KNNWithMeans with k=50...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2342894543131402 for KNNWithMeans with k=50
#
# Evaluating KNNWithZScore with k=50...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# MAE: 1.2307127810633058 for KNNWithZScore with k=50
#
# Best algorithm: KNNWithZScore with k=50 having MAE: 1.2307127810633058
