# %% [markdown]
# # HISTOGRAMME ET INTERPRÉTATION

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore', category=UserWarning)

# %%
avis = pd.read_csv('./avis.csv')
avis.fillna('', inplace=True)
avis.head()
# Out:
#                author       date_published  \
# 0  Monsieur Guillaume  2021-01-27 11:06:44
# 1          morlockbob  2020-10-18 10:04:21
# 2              SwatSh  2021-02-01 08:35:08
# 3     Timi JeuxATheme  2020-11-19 17:04:57
# 4           prunelles  2021-05-24 12:43:18
#
#                           title_review  note  \
# 0  Voyages sur les ailes des papillons     8
# 1             le festival de Michoacan     7
# 2     Vivez la migration des monarques     7
# 3                                  Bon     8
# 4                          Envolez-moi     9
#
#                                          review_href      title  \
# 0  "https://www.trictrac.net/avis/vraiment-bon-12...  Mariposas
# 1  "https://www.trictrac.net/avis/le-festival-de-...  Mariposas
# 2  "https://www.trictrac.net/avis/vivez-la-migrat...  Mariposas
# 3                                                     Mariposas
# 4        "https://www.trictrac.net/avis/envolez-moi"  Mariposas
#
#                                                  url  treated  \
# 0  https://www.trictrac.net/jeu-de-societe/maripo...        1
# 1  https://www.trictrac.net/jeu-de-societe/maripo...        1
# 2  https://www.trictrac.net/jeu-de-societe/maripo...        1
# 3  https://www.trictrac.net/jeu-de-societe/maripo...        1
# 4  https://www.trictrac.net/jeu-de-societe/maripo...        1
#
#                                              comment
# 0  Lorsque le jeu est jeu, bon, réflexif, joli po...
# 1  Comment continuer après un mega hit ? Simpleme...
# 2  Vin d'jeu: Avec Mariposas, Elizabeth Hargrave ...
# 3
# 4  Très joli bijou que ce jeu-là ! Le matériel, l...

# %%
details = pd.read_csv("./details_processed.csv")
details.fillna('',inplace=True)
details.head()
# Out:
#                                           categories  \
# 0
# 1
# 2  Enchères|Aventures dans la jungle|Collection /...
# 3
# 4  Card-driven|Combinaison|Coopération|Deck build...
#
#                                              casting  \
# 0  Par Eric Lang et Andrea ChiarvesioIllustré par...
# 1  Par Elizabeth HargraveIllustré par Matt Paquet...
# 2  Par Alexandre GarciaIllustré par Nastya LehnÉd...
# 3                Édité par Arkhane Asylum Publishing
# 4  Par Maxime Rambourg et Théo RivièreIllustré pa...
#
#                       gameplay  \
# 0        1 à 4|14 ans et +|45
# 1        2 à 5|14 ans et +|60
# 2         2 à 5|8 ans et +|45
# 3  à partir de 1|12 ans et +|~
# 4        1 à 4|12 ans et +|60
#
#                                          description  \
# 0  \n                      Marvel United : Unis c...
# 1  \n                      Chaque année, au print...
# 2  \n                      Vous êtes à la tête d’...
# 3  \n                      Un Kit de démarrage co...
# 4  \n                      Le Dr Foo a créé une t...
#
#                         full_title  \
# 0             Marvel United (2020)
# 1                 Mariposas (2020)
# 2                   Quetzal (2020)
# 3  Alien - Kit de Démarrage (2020)
# 4                  The LOOP (2020)
#
#                                                  url  Note  Nombre d'avis  \
# 0  https://www.trictrac.net/jeu-de-societe/marvel...  7.58           19.0
# 1  https://www.trictrac.net/jeu-de-societe/mariposas  7.39           33.0
# 2    https://www.trictrac.net/jeu-de-societe/quetzal  8.18           28.0
# 3  https://www.trictrac.net/jeu-de-societe/alien-...  9.00            4.0
# 4   https://www.trictrac.net/jeu-de-societe/the-loop  8.75           72.0
#
#    Note Finkel
# 0         8.74
# 1         7.68
# 2         7.42
# 3         0.00
# 4         9.70

# %%
category_counts = np.zeros(30)

for category in details["categories"]:
    sections = category.split('|')
    section_count = len(sections)
    if category == '':  # Vérifiez si le nombre de sections est égal à zéro
        category_counts[0] += 1
    else:
        category_counts[section_count] += 1

# %%
# Création des valeurs pour l'axe des abscisses (ajustées pour inclure le zéro)
x_values = np.arange(len(category_counts) + 1)
# Création de l'histogramme
plt.figure(figsize=(15, 6))
plt.bar(x_values[:-1], category_counts, color='skyblue')  # Utilisez x_values[:-1] pour exclure le dernier élément
plt.yscale('log')
# Ajout des étiquettes et du titre
plt.xlabel('Nombre de catégories')
plt.ylabel('Nombre de jeux')
plt.title('Histogramme du nombre de jeux selon le nombre de catégories')
plt.xticks(np.arange(30))
# Affichage 
plt.show()

# %% [markdown]
# Il y a 2198 jeux qui n'ont pas de catégorie du tout, ce qui pourrait indiquer une absence de classification pour ces jeux.\
# La majorité des jeux (11581) sont associés à une seule catégorie, ce qui peut être considéré comme une classification simple et claire.\
# Ensuite, on observe une diminution du nombre de jeux à mesure que le nombre de catégories augmente, bien que certains jeux soient associés à un nombre relativement élevé de catégories (27 au maximum dans ce cas).

# %%
# Charger le DataFrame
occ_categories = pd.read_csv("./occurrences_par_categorie.csv")

# Enleve la catégorie 'Autres' et Nan focer pour ce graphe
occ_categories_filtered = occ_categories.dropna(subset=['categories'])
occ_categories_filtered = occ_categories_filtered[occ_categories_filtered['categories'] != 'Autres']

# Trier le DataFrame filtré par la colonne 'count' de manière décroissante et sélectionner les 20 premières lignes
top_20_categories = occ_categories_filtered.sort_values(by='count', ascending=False).head(21)

# Créer un histogramme avec sns.barplot
plt.figure(figsize=(10, 6))
sns.barplot(data=top_20_categories, x='categories', y='count', hue='categories', palette='viridis', legend=False)
plt.xticks(rotation=45, ha='right')  # Rotation des étiquettes sur l'axe des x pour une meilleure lisibilité
plt.xlabel('Catégories')
plt.ylabel("Nombre d'occurrences")
plt.title('Histogramme des 20 catégories les plus fréquentes')
plt.tight_layout()
plt.show()

# %%
# Out:
# Jeux de plateau
# Jeux de cartes
# Guerre
# Affrontement
# Jeu de carte à collectionner
# Jeux de connaissances
# Hasard (Dé, Cartes, ...)
# Jeux de pions
# Casse-tête
# Jeux de figurines
# Placement
# Déplacement
# Combinaison
# Ambiance
# Jeu de logique
# Médiéval-fantastique
# Dés
# Jeux de dés
# Exploration
# Coopération
