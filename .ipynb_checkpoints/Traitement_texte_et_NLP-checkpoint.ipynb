# %% [markdown]
# # Traitement de texte et NLP

# %%
# on importe les differentes librairies
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import spacy
import networkx as nx
import nltk
import scipy

# on importe les different module pour le traitement de texte
from gensim.utils import simple_preprocess
from wordcloud import WordCloud
from collections import Counter
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.util import ngrams
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# on importe notre bdd
avis_norm = pd.read_csv("BDD/avis_norm.csv")

# %%
avis_norm.head(1)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
# Out:
#    Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0             0             0             0             0           0
#
#                author date_published                         title_review  \
# 0  Monsieur Guillaume        2021-01  Voyages sur les ailes des papillons
#
#    note      title                                                url  \
# 0   0.8  Mariposas  https://www.trictrac.net/jeu-de-societe/maripo...
#
#                                              comment  \
# 0  Lorsque le jeu est jeu, bon, réflexif, joli po...
#
#                                       comment_propre  \
# 0  lorsque est bon réflexif joli est sensible sty...
#
#    nombre_mots_comment_propre
# 0                          59

# %%
# Charger le modèle de langue française
nlp = spacy.load('fr_core_news_sm')

# Fonction adaptée pour traiter chaque commentaire individuellement
def filtrer_commentaire(commentaire):
    doc = nlp(commentaire)
    # Définir les types de mots à exclure (les verbes ne sont pas exclus)
    pos_exclues = ['DET', 'CONJ', 'PRON', 'ADP', 'CCONJ', 'PUNCT']
    #mots_exclus = ['jeu', 'jeux'] and token.lemma_.lower() not in mots_exclus
    # Filtrer les tokens en se basant sur les types de mots et la lemmatisation
    mots_filtres = [token.text for token in doc if token.pos_ not in pos_exclues ]
    return ' '.join(mots_filtres)

# Exemple d'utilisation
avis_norm = pd.DataFrame({'comment': ["Le jeu est vraiment intéressant et bien fait."]})
avis_norm['comment'] = avis_norm['comment'].astype(str)
avis_norm['comment_filtre'] = avis_norm['comment'].apply(filtrer_commentaire)

print(avis_norm['comment_filtre'])
# Out:
# 0    jeu est vraiment intéressant bien fait
# Name: comment_filtre, dtype: object

# %%
# Utilisation de simple_preprocess pour nettoyer les commentaires
avis_norm['comment_propre'] = avis_norm['comment'].apply(lambda x: ' '.join(simple_preprocess(x)))

# Appliquer la fonction de filtrage et sauvegarder le résultat dans la même colonne
avis_norm['comment_propre'] = avis_norm['comment_propre'].apply(filtrer_commentaire)

# Calcul de la longueur des commentaires en termes de nombre de mots
avis_norm['nombre_mots_comment_propre'] = avis_norm['comment_propre'].apply(lambda x: len(x.split()))
avis_norm.to_csv("BDD/avis_norm.csv")

# %%
# Obtenir des statistiques descriptives pour les longueurs de commentaires
statistiques_longueurs = avis_norm['nombre_mots_comment_propre'].describe()

# Afficher les statistiques
print(statistiques_longueurs)

# %%
# Filtrage des commentaires longs en utilisant un seuil spécifique basé sur le nombre de mots
seuil_nombre_mots = 70 # Considéré comme long s'il contient plus de 70 mots 25% des commentaires plus long
commentaires_longs = avis_norm[avis_norm['nombre_mots_comment_propre'] > seuil_nombre_mots]['comment_propre'].tolist()

# nombre de commentaires longs
print(f"Nombre de commentaires longs : {len(commentaires_longs)}")

for i in range(0,100):
    print(f"\ncommentaires {i} \n")
    print(commentaires_longs[i])

# %%
# Joindre tous les commentaires longs en une seule chaîne de texte
texte_long = " ".join(commentaires_longs)

# Créer un objet WordCloud
nuage_de_mots = WordCloud(background_color='white', max_words=100, contour_color='steelblue')

# Générer le nuage de mots
nuage_de_mots.generate(texte_long)

# Afficher le nuage de mots avec matplotlib
plt.figure(figsize=(10, 7))
plt.imshow(nuage_de_mots, interpolation='bilinear')
plt.axis('off')  # Ne pas afficher les axes pour une meilleure visualisation
plt.show()

# %%
# Calculer les 100 mots les plus fréquents dans la chaîne de texte longue
mots_frequents = Counter(texte_long.split()).most_common(100)
for f in mots_frequents:
    print(f)

# %% [markdown]
# **Analyse de co-occurrence et réseaux de mots / N-grammes**

# %%
# Tokenisation
tokens = word_tokenize(texte_long, language='french')

# Génération des bigrammes
bigrammes = list(ngrams(tokens, 2))

# Comptage des bigrammes les plus fréquents
freq_bigrammes = Counter(bigrammes)
print(freq_bigrammes.most_common(15))

# %% [markdown]
# **Comparer le vocabulaire entre les différents utilisateurs.**

# %%
# Assurez-vous d'abord de remplacer les valeurs NaN par une chaîne vide ou par un placeholder approprié
df_grouped = avis_norm.fillna('')

# Ensuite, regroupez les commentaires par auteur et les concaténez en un seul texte, en s'assurant que tout est traité comme une chaîne
df_grouped = avis_norm.groupby('author')['comment_propre'].apply(lambda x: ' '.join(x.astype(str))).reset_index()

# Limiter à 100 auteurs si nécessaire (vous avez mentionné 10 dans la demande initiale, mais utilisé 100 ici)
df_limited = df_grouped.head(100)

# Charger les stop words en français
stop_words_french = stopwords.words('french')

# Prétraitement et vectorisation TF-IDF avec les stop words français de nltk
vectorizer = TfidfVectorizer(stop_words=stop_words_french)
X = vectorizer.fit_transform(df_grouped['comment_propre'])

# Le reste du code reste inchangé
knn = NearestNeighbors(n_neighbors=4, metric='cosine')
knn.fit(X)

# Trouver les auteurs les plus proches pour chaque auteur, en ignorant le premier résultat
distances, indices = knn.kneighbors(X)

for i in range(len(df_grouped)):
    print(f"Auteurs les plus similaires à {df_grouped.iloc[i]['author']}:")
    for j in range(1, 4):  # Commence à 1 pour ignorer l'auto-recommandation et imprime les 3 suivants
        if j < len(df_grouped):  # Vérifie si l'indice est dans la plage
            print(f"- {df_grouped.iloc[indices[i, j]]['author']} avec une distance de {distances[i, j]:.2f}")
    print()
# Out:
# - The Killer avec une distance de 0.39
#
# Auteurs les plus similaires à vermithrax79:
# - Bubu2015 avec une distance de 0.65
# - ludodelaludo avec une distance de 0.65
# - Shakkah avec une distance de 0.65
#
# Auteurs les plus similaires à vik:
# - morlockbob avec une distance de 0.41
# - JJL avec une distance de 0.41
# - meliadus94 avec une distance de 0.41
#
# Auteurs les plus similaires à viking:
# - Joker75 avec une distance de 0.37
# - Lilian avec une distance de 0.39
# - meliadus94 avec une distance de 0.39
#
# Auteurs les plus similaires à vince47:
# - O_cedar avec une distance de 0.58
# - JJL avec une distance de 0.59
# - prems avec une distance de 0.59
#
# Auteurs les plus similaires à vince_jeux:
# - Golden avec une distance de 0.62
# - Pac avec une distance de 0.63
# - meliadus94 avec une distance de 0.63
#
# Auteurs les plus similaires à vinced:
# - epave de pwasson avec une distance de 0.78
# - grojaky avec une distance de 0.78
# - ijonesjeux avec une distance de 0.79
#
# Auteurs les plus similaires à vindix:
# - ddbas avec une distance de 0.66
# - romjé avec une distance de 0.67
# - Bis Minami avec une distance de 0.67
#
# Auteurs les plus similaires à violette:
# - JJL avec une distance de 0.48
# - prems avec une distance de 0.50
# - lynkowsky avec une distance de 0.50
#
# Auteurs les plus similaires à vlad:
# - pierre2.0 avec une distance de 0.41
# - JJL avec une distance de 0.41
# - limp avec une distance de 0.42
#
# Auteurs les plus similaires à vonashol:
# - JJL avec une distance de 0.53
# - limp avec une distance de 0.53
# - cedha2000 avec une distance de 0.53
#
# Auteurs les plus similaires à vool:
# - Lilian avec une distance de 0.58
# - Pifec avec une distance de 0.58
# - meliadus94 avec une distance de 0.59
#
# Auteurs les plus similaires à vwvw:
# - speanuts avec une distance de 0.71
# - jeuxest avec une distance de 0.72
# - Pifec avec une distance de 0.73
#
# Auteurs les plus similaires à warlath:
# - meliadus94 avec une distance de 0.26
# - redeagle avec une distance de 0.26
# - morlockbob avec une distance de 0.27
#
# Auteurs les plus similaires à warriorban:
# - lynkowsky avec une distance de 0.47
# - limp avec une distance de 0.47
# - Lilian avec une distance de 0.47
#
# Auteurs les plus similaires à wesley:
# - glouglou avec une distance de 0.43
# - Djez avec une distance de 0.43
# - Pifec avec une distance de 0.44
#
# Auteurs les plus similaires à wildwillo007:
# - cedha2000 avec une distance de 0.58
# - Lunedor avec une distance de 0.59
# - meliadus94 avec une distance de 0.59
#
# Auteurs les plus similaires à william150574:
# - Harry Cover avec une distance de 0.48
# - studiordl avec une distance de 0.52
# - googa avec une distance de 0.53
#
# Auteurs les plus similaires à willnova:
# - emmanuel.denis avec une distance de 0.00
# - echow464 avec une distance de 0.00
# - Godoftheark avec une distance de 0.00
#
# Auteurs les plus similaires à willowpet:
# - emmanuel.denis avec une distance de 0.00
# - echow464 avec une distance de 0.00
# - Godoftheark avec une distance de 0.00
#
# Auteurs les plus similaires à winforlife:
# - meliadus94 avec une distance de 0.44
# - Lililice avec une distance de 0.44
# - pierre2.0 avec une distance de 0.44
#
# Auteurs les plus similaires à witloof:
# - JJL avec une distance de 0.57
# - pierre2.0 avec une distance de 0.57
# - lynkowsky avec une distance de 0.58
#
# Auteurs les plus similaires à wizz50:
# - Pifec avec une distance de 0.44
# - allard92 avec une distance de 0.46
# - cedha2000 avec une distance de 0.46
#
# Auteurs les plus similaires à wizzy:
# - ManuFitz avec une distance de 0.67
# - Gigi avec une distance de 0.72
# - morlockbob avec une distance de 0.72
#
# Auteurs les plus similaires à wolftruck:
# - Pso76 avec une distance de 0.68
# - JJL avec une distance de 0.69
# - glouglou avec une distance de 0.69
#
# Auteurs les plus similaires à wompat:
# - momov avec une distance de 0.54
# - lynkowsky avec une distance de 0.54
# - shambhala avec une distance de 0.54
#
# Auteurs les plus similaires à wondermiloose:
# - pierre2.0 avec une distance de 0.63
# - limp avec une distance de 0.63
# - JJL avec une distance de 0.64
#
# Auteurs les plus similaires à x-men:
# - meliadus94 avec une distance de 0.60
# - Lilian avec une distance de 0.61
# - allard92 avec une distance de 0.61
#
# Auteurs les plus similaires à xavier44:
# - limp avec une distance de 0.49
# - JJL avec une distance de 0.52
# - scand1sk avec une distance de 0.53
#
# Auteurs les plus similaires à xqwix:
# - limp avec une distance de 0.50
# - Graham avec une distance de 0.51
# - O_cedar avec une distance de 0.51
#
# Auteurs les plus similaires à yackonline:
# - prems avec une distance de 0.62
# - dabiglulu avec une distance de 0.63
# - Jones avec une distance de 0.63
#
# Auteurs les plus similaires à yahndrev:
# - momov avec une distance de 0.42
# - Pifec avec une distance de 0.43
# - Marc Laumonier avec une distance de 0.46
#
# Auteurs les plus similaires à yannLM:
# - Gaélion avec une distance de 0.06
# - druidasse avec une distance de 0.06
# - docjoky avec une distance de 0.06
#
# Auteurs les plus similaires à ybkam:
# - JJL avec une distance de 0.24
# - pierre2.0 avec une distance de 0.25
# - Joker75 avec une distance de 0.26
#
# Auteurs les plus similaires à yelf:
# - JJL avec une distance de 0.54
# - Lilian avec une distance de 0.55
# - limp avec une distance de 0.55
#
# Auteurs les plus similaires à yoda37:
# - Djez avec une distance de 0.37
# - Pifec avec une distance de 0.39
# - allard92 avec une distance de 0.41
#
# Auteurs les plus similaires à yolace:
# - nim avec une distance de 0.85
# - patrice_m avec une distance de 0.87
# - Ingalls avec une distance de 0.87
#
# Auteurs les plus similaires à yugg:
# - Pifec avec une distance de 0.72
# - starvince avec une distance de 0.72
# - cedha2000 avec une distance de 0.72
#
# Auteurs les plus similaires à yuhhh45:
# - lynkowsky avec une distance de 0.64
# - prems avec une distance de 0.65
# - limp avec une distance de 0.65
#
# Auteurs les plus similaires à yvon de tarwac:
# - lynkowsky avec une distance de 0.56
# - cedha2000 avec une distance de 0.57
# - Pascalito avec une distance de 0.58
#
# Auteurs les plus similaires à zacc63:
# - dabiglulu avec une distance de 0.55
# - limp avec une distance de 0.55
# - JJL avec une distance de 0.56
#
# Auteurs les plus similaires à zachtman:
# - guilou05 avec une distance de 0.54
# - JJL avec une distance de 0.54
# - limp avec une distance de 0.55
#
# Auteurs les plus similaires à zango:
# - --- JD --- avec une distance de 0.39
# - cyem817 avec une distance de 0.39
# - Gaïa avec une distance de 0.39
#
# Auteurs les plus similaires à zangui-F:
# - Joker75 avec une distance de 0.55
# - limp avec une distance de 0.55
# - DidOo avec une distance de 0.56
#
# Auteurs les plus similaires à zanzeoo:
# - Bis Minami avec une distance de 0.47
# - redeagle avec une distance de 0.48
# - meliadus94 avec une distance de 0.48
#
# Auteurs les plus similaires à zapata:
# - maksen avec une distance de 0.63
# - Logan avec une distance de 0.64
# - limp avec une distance de 0.64
#
# Auteurs les plus similaires à zatistine:
# - limp avec une distance de 0.29
# - grolapinos avec une distance de 0.30
# - JJL avec une distance de 0.30
#
# Auteurs les plus similaires à zebulon:
# - trisskel avec une distance de 0.36
# - Equilibrium7 avec une distance de 0.41
# - limp avec une distance de 0.42
#
# Auteurs les plus similaires à zeroxceet:
# - limp avec une distance de 0.61
# - JJL avec une distance de 0.62
# - Grogan23 avec une distance de 0.62
#
# Auteurs les plus similaires à zharg le borgne:
# - prems avec une distance de 0.78
# - Pilpoil avec une distance de 0.79
# - Firemael avec une distance de 0.79
#
# Auteurs les plus similaires à zico:
# - redeagle avec une distance de 0.39
# - Grovast avec une distance de 0.39
# - meliadus94 avec une distance de 0.40
#
# Auteurs les plus similaires à zinv:
# - limp avec une distance de 0.56
# - pierre2.0 avec une distance de 0.57
# - silkim avec une distance de 0.58
#
# Auteurs les plus similaires à ziwzaw:
# - JJL avec une distance de 0.51
# - dabiglulu avec une distance de 0.52
# - pierre2.0 avec une distance de 0.52
#
# Auteurs les plus similaires à zombywoof:
# - elyrelle avec une distance de 0.01
# - GillesB16 avec une distance de 0.01
# - Geetaku avec une distance de 0.01
#
# Auteurs les plus similaires à zorghk:
# - limp avec une distance de 0.57
# - romjé avec une distance de 0.57
# - Joker75 avec une distance de 0.58
#
# Auteurs les plus similaires à zorglub:
# - ijonesjeux avec une distance de 0.51
# - grojaky avec une distance de 0.52
# - moiseursula avec une distance de 0.53
#
# Auteurs les plus similaires à zorl:
# - JJL avec une distance de 0.49
# - lynkowsky avec une distance de 0.50
# - Pifec avec une distance de 0.50
#
# Auteurs les plus similaires à §Gama§:
# - Lilian avec une distance de 0.70
# - pierre2.0 avec une distance de 0.70
# - Grovast avec une distance de 0.70
#
# Auteurs les plus similaires à égécriéaline:
# - Mattintheweb avec une distance de 0.46
# - ludodelaludo avec une distance de 0.47
# - beRtuj avec une distance de 0.48

# %%
# Filtrer les commentaires de l'auteur 'Adouskar' et afficher les colonnes 'title_review' et 'comment'
print("Les commentaires de 20.100:")
print(avis_norm.loc[avis_norm['author'] == '20.100', ['title_review', 'comment','note']])

# Filtrer les commentaires de l'auteur 'echow464' et afficher les colonnes 'title_review' et 'comment'
print("\nLes commentaires de JJL :")
print(avis_norm.loc[avis_norm['author'] == 'JJL', ['title_review', 'comment','note']])
